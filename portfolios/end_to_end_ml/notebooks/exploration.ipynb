# %% [markdown]
# # Exploration (optional)
# Use scripts for the pipeline; notebook is optional for quick checks.

# %%
import pandas as pd
df = pd.read_csv('data/raw/online_retail.csv', encoding='ISO-8859-1')
df.head()
